# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
data = keras.datasets.fashion_mnist

# %%
(train_images, train_labels), (test_images, test_labels) = data.load_data()
# Out:
# ...
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
print(tf.__version__)
# Out:
# 2.3.0

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']

# %%
train_images = train_images/255.0
test_images = test_images/255.0

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128, activation="relu"),
    keras.layers.Dense(10, activation="softmax")
    ])

model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
model.fit(train_images, train_labels, epochs=5) 
#epochs means the time(order) will repeat
test_loss, test_acc = model.evaluate(test_images, test_labels)
print("Tested Acc:", test_acc)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.5004 - accuracy: 0.8251
# Epoch 2/5
# 1875/1875 [==============================] - 2s 803us/step - loss: 0.3772 - accuracy: 0.8641
# Epoch 3/5
# 1875/1875 [==============================] - 1s 685us/step - loss: 0.3379 - accuracy: 0.8769
# Epoch 4/5
# 1875/1875 [==============================] - 1s 661us/step - loss: 0.3132 - accuracy: 0.8855
# Epoch 5/5
# ...
# 313/313 [==============================] - 0s 462us/step - loss: 0.3554 - accuracy: 0.8704
# Tested Acc: 0.8704000115394592

# %%
prediction = model.predict(test_images)
plt.figure(figsize=(16, 16))
for i in range(12):
    plt.grid(False)
    ax=plt.subplot(3, 4, i+1)
    plt.imshow(test_images[i]) #, cmap=plt.cm.binary)
    plt.xlabel("Actual: " + class_names[test_labels[i]])
    plt.title("Prediction : " + class_names[np.argmax(prediction[i])])
    #plt.show()

# %%
print(len(train_images))
# Out:
# 60000

# %%
for x in range(0):
  for y in test_images:
    print(y)
print(test_images[1].shape   )

from PIL import Image 
  
# Read image 
new_im = Image.new('RGB', (28, 28))

#images = [new_im.open(x) for x in ['ankleboot.png']]
# new_im.paste(im, (x_offset,0))
img = Image.open('ankleboot.png') 
img2 = Image.open('cloth.png') 
new_im.paste(img, (0,0))
print(new_im)
print()
# Out:
# (28, 28)
# <PIL.Image.Image image mode=RGB size=28x28 at 0x7FA47F662BB0>

# %%
#print(train_images)
#print(np.dtype)
#print(type(train_images))
#print(np.ndim)

# %%
kk=np.concatenate((test_images, [train_images[1]]))
print(np.shape)
print(np.dtype)
print(type(np))
print(np.ndim)

from PIL import Image 
  
# Read image 
new_im = Image.new('RGB', (28, 28))

#images = [new_im.open(x) for x in ['ankleboot.png']]
# new_im.paste(im, (x_offset,0))
img = Image.open('ankleboot.png') 
img2 = Image.open('cloth.png') 

new_im.paste(img, (0,0))
    
# Output Images 
img.show()
img=img2
img.show()

print(plt.imshow(train_images[1]))
print(img)
mm = train_images[1]

train_images[1] = img
print( plt.imshow(mm))
# Out:
# <function shape at 0x7fa4c817d4c0>
# <class 'numpy.dtype'>
# <class 'module'>
# <function ndim at 0x7fa4c8181af0>
# AxesImage(54,36;334.8x217.44)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=251x248 at 0x7FA46775C2E0>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-d60b334cb31c> in <module>
#      26 mm = train_images[1]
#      27
# ---> 28 train_images[1] = img
#      29 print( plt.imshow(mm))
#
# ValueError: assignment destination is read-only

# %%
from PIL import Image 
  
# Read image 
new_im = Image.new('RGB', (28, 28))

#images = [new_im.open(x) for x in ['ankleboot.png']]
# new_im.paste(im, (x_offset,0))
img = Image.open('ankleboot.png') 
new_im.paste(img, (0,0))
    
# Output Images 
img.show() 
print(type(img))
print(type(test_images[1]))
#print(test_images[1])
#kk=np.concatenate((test_images, [train_images[1]]))
#kk=np.concatenate((test_images, img))
#append one label array [1] to the end of test_label
#kk=np.concatenate((test_images, [1]))
print(len(test_images))
print(len(kk))
#print(len(kk))
# Out:
# <class 'PIL.PngImagePlugin.PngImageFile'>
# <class 'numpy.ndarray'>
# 10000
# 10001

# %%
#how to append array in numpy
a = np.array([[1, 2, 3], [4, 5, 6]])
b = np.array([[9, 8, 7], [6, 5, 4]])

np.concatenate((a, b))
# Out:
# array([[1, 2, 3],
#        [4, 5, 6],
#        [9, 8, 7],
#        [6, 5, 4]])

# %%
#print(train_labels[1])
for i in range(5):
    plt.grid(False)
    plt.imshow(train_images[i]) #, cmap=plt.cm.binary)
    #plt.xlabel("The label name: " + class_names[train_labels[i]])
    plt.title("The label : " + str(train_labels[i]) + ", The label name: " + class_names[train_labels[i]])
    plt.show()

# %%
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4982 - accuracy: 0.8248
# Epoch 2/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3746 - accuracy: 0.8637
# Epoch 3/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3379 - accuracy: 0.8770
# Epoch 4/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3123 - accuracy: 0.8854
# Epoch 5/5
# ...
# 313/313 [==============================] - 0s 1ms/step - loss: 0.3569 - accuracy: 0.8742
# Tested Acc: 0.8741999864578247

# %%
print(test_acc)
# Out:
# 0.8569999933242798

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128, activation="relu"),
    keras.layers.Dense(10, activation="softmax")
    ])

model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
model.fit(train_images, train_labels, epochs=5) 
#epochs means the time(order) will repeat
test_loss, test_acc = model.evaluate(test_images, test_labels)
print("Tested Acc:", test_acc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7b0669093d83> in <module>
# ----> 1 model = keras.Sequential([
#       2     keras.layers.Flatten(input_shape=(28,28)),
#       3     keras.layers.Dense(128, activation="relu"),
#       4     keras.layers.Dense(10, activation="softmax")
#       5     ])
#
# NameError: name 'keras' is not defined
